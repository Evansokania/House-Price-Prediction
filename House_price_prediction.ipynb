# %% [markdown]
# <a href="https://colab.research.google.com/github/Evansokania/House-Price-Prediction/blob/main/House_price_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import OneHotEncoder,StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
# import dataset
df = pd.read_csv('/content/realtor-data.zip.csv')
# display 20 random records
df.sample(20)
# Out:
#          status  bed  bath  acre_lot          city           state  zip_code  \
# 1747   for_sale  5.0   2.0      0.49       Arecibo     Puerto Rico     612.0
# 9153   for_sale  3.0   2.0      0.09        Manati     Puerto Rico     674.0
# 3160   for_sale  NaN   NaN      0.12       Florida     Puerto Rico     650.0
# 25584  for_sale  4.0   2.0      0.09      Carolina     Puerto Rico     979.0
# 27751  for_sale  3.0   2.0       NaN      San Juan     Puerto Rico     926.0
# 25140  for_sale  3.0   2.0      0.20       Amherst   Massachusetts    1002.0
# 18788  for_sale  3.0   3.0       NaN      San Juan     Puerto Rico     926.0
# 15676  for_sale  3.0   3.0       NaN         Loiza     Puerto Rico     772.0
# 8486   for_sale  4.0   4.0   2500.00        Caguas     Puerto Rico     725.0
# 11089  for_sale  NaN   NaN     12.14      San Juan     Puerto Rico     926.0
# 9819   for_sale  3.0   2.0      0.26       Humacao     Puerto Rico     792.0
# 7255   for_sale  3.0   1.0       NaN      San Juan     Puerto Rico     925.0
# 7879   for_sale  5.0   2.0      0.22      San Juan     Puerto Rico     924.0
# 11284  for_sale  NaN   NaN      7.82  Saint Thomas  Virgin Islands     802.0
# 16863  for_sale  2.0   2.0       NaN      Carolina     Puerto Rico     979.0
# 30572  for_sale  8.0   4.0      0.24    Pittsfield   Massachusetts    1201.0
# 6355   for_sale  7.0   5.0      0.10       Bayamon     Puerto Rico     959.0
# 21647  for_sale  3.0   1.0      0.17      Toa Alta     Puerto Rico     953.0
# 26001  for_sale  NaN   NaN      0.51         Cidra     Puerto Rico     739.0
# 16539  for_sale  3.0   1.0      0.05        Dorado     Puerto Rico     646.0
#
#        house_size prev_sold_date      price
# 1747       2058.0            NaN   148000.0
# 9153       2417.0            NaN    70000.0
# 3160          NaN            NaN    28000.0
# 25584      1600.0            NaN   114000.0
# 27751      1500.0            NaN   229000.0
# 25140      1349.0     2005-09-02   439900.0
# 18788      1550.0            NaN   265000.0
# 15676      1249.0            NaN   161000.0
# 8486       4400.0            NaN   795000.0
# 11089         NaN            NaN   500000.0
# 9819       1250.0            NaN    96000.0
# 7255        805.0            NaN    77000.0
# 7879       1664.0            NaN    83000.0
# 11284         NaN            NaN  1500000.0
# 16863      1138.0            NaN   569000.0
# 30572      3344.0     1992-04-30   169000.0
# 6355       2500.0            NaN   195000.0
# 21647      1027.0            NaN    92500.0
# 26001         NaN            NaN    48500.0
# 16539       816.0            NaN    95600.0

# %%
#drop null values in the dataset
df.dropna(inplace=True)

# %%
#check the datatypes of the columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1829 entries, 829 to 32897
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   status          1829 non-null   object
#  1   bed             1829 non-null   float64
#  2   bath            1829 non-null   float64
#  3   acre_lot        1829 non-null   float64
#  4   city            1829 non-null   object
#  5   state           1829 non-null   object
#  6   zip_code        1829 non-null   float64
#  7   house_size      1829 non-null   float64
#  8   prev_sold_date  1829 non-null   object
#  9   price           1829 non-null   float64
# dtypes: float64(6), object(4)
# memory usage: 157.2+ KB

# %%
#convert prev_sold_date column to datetime data type
df.prev_sold_date = pd.to_datetime(df.prev_sold_date)
# convert zip_code into an object(string) since it is a categorical variable
df.zip_code = df.zip_code.astype(int)
df.zip_code = df.zip_code.astype(str)

# Extract year from the parse_version
df['prev_sold_date'] = df['prev_sold_date'].dt.year
df = df.rename(columns={'prev_sold_date': 'year_sold'})
df
# Out:
#          status  bed  bath  acre_lot         city          state zip_code  \
# 829    for_sale  7.0   3.0      0.09       Dorado    Puerto Rico      949
# 3380   for_sale  7.0   3.0      0.09       Dorado    Puerto Rico      949
# 5083   for_sale  7.0   3.0      0.09       Dorado    Puerto Rico      949
# 5387   for_sale  7.0   3.0      0.09       Dorado    Puerto Rico      949
# 9053   for_sale  7.0   3.0      0.09       Dorado    Puerto Rico      949
# ...         ...  ...   ...       ...          ...            ...      ...
# 32892  for_sale  3.0   3.0      0.92  Glastonbury    Connecticut     6033
# 32893  for_sale  3.0   1.0      1.30       Monson  Massachusetts     1057
# 32894  for_sale  3.0   2.0      0.17   Manchester    Connecticut     6040
# 32895  for_sale  3.0   3.0      1.00      Tolland    Connecticut     6084
# 32897  for_sale  8.0   3.0      0.39       Palmer  Massachusetts     1069
#
#        house_size  year_sold     price
# 829        1192.0       2019  110000.0
# 3380       1192.0       2019  110000.0
# 5083       1192.0       2019  110000.0
# 5387       1192.0       2019  110000.0
# 9053       1192.0       2019  110000.0
# ...           ...        ...       ...
# 32892      1430.0       2019  439000.0
# 32893      1674.0       2018  290000.0
# 32894      1521.0       2005  209900.0
# 32895      1234.0       1993  239999.0
# 32897      4841.0       2015  335000.0
#
# [1829 rows x 10 columns]

# %% [markdown]
# #### PREPROCESSING

# %%
#seperate dataset into features and target variable
X = df.drop('price', axis = 1)
y = df['price']

# %%
# Preprocessing pipeline for numerical and categorical features

numerical_features = X.select_dtypes(include=['int64','int32' ,'float64']).columns
categorical_features = X.select_dtypes(include=['object']).columns

numerical_transformer = Pipeline(steps=[
    ('scaler', StandardScaler())
])

categorical_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_features),
        ('cat', categorical_transformer, categorical_features)
    ]
)



# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.35)

# %%
# Create a pipeline with preprocessing and regressor
pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('regressor', RandomForestRegressor())
])

# Define hyperparameters for tuning
param_grid = {
    'regressor__n_estimators': [100, 175, 300],
    'regressor__max_depth': [None, 10, 20],
    'regressor__min_samples_split': [2, 5, 10]
}

# %% [markdown]
# #### MODELING

# %%
# Perform grid search with cross-validation
grid_search = GridSearchCV(pipeline, param_grid, cv=5, scoring='neg_mean_squared_error', verbose=3)
grid_search.fit(X_train, y_train)

# Evaluate the best model from grid search
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# [CV 1/5] END regressor__max_depth=None, regressor__min_samples_split=2, regressor__n_estimators=100;, score=-1071465815868.935 total time=   2.5s
# [CV 2/5] END regressor__max_depth=None, regressor__min_samples_split=2, regressor__n_estimators=100;, score=-11764077966.554 total time=   2.8s
# [CV 3/5] END regressor__max_depth=None, regressor__min_samples_split=2, regressor__n_estimators=100;, score=-29757027809.293 total time=   2.7s
# [CV 4/5] END regressor__max_depth=None, regressor__min_samples_split=2, regressor__n_estimators=100;, score=-42806230507.180 total time=   4.7s
# [CV 5/5] END regressor__max_depth=None, regressor__min_samples_split=2, regressor__n_estimators=100;, score=-11390992294.278 total time=   1.9s
# [CV 1/5] END regressor__max_depth=None, regressor__min_samples_split=2, regressor__n_estimators=175;, score=-1106580422226.424 total time=   2.3s
# [CV 2/5] END regressor__max_depth=None, regressor__min_samples_split=2, regressor__n_estimators=175;, score=-10497490838.393 total time=   2.3s
# [CV 3/5] END regressor__max_depth=None, regressor__min_samples_split=2, regressor__n_estimators=175;, score=-34447114163.108 total time=   2.4s
# [CV 4/5] END regressor__max_depth=None, regressor__min_samples_split=2, regressor__n_estimators=175;, score=-42881561000.377 total time=   2.9s
# [CV 5/5] END regressor__max_depth=None, regressor__min_samples_split=2, regressor__n_estimators=175;, score=-10009500491.565 total time=   2.9s
# [CV 1/5] END regressor__max_depth=None, regressor__min_samples_split=2, regressor__n_estimators=300;, score=-1088098722995.931 total time=   4.0s
# [CV 2/5] END regressor__max_depth=None, regressor__min_samples_split=2, regressor__n_estimators=300;, score=-9617621135.925 total time=   4.0s
# [CV 3/5] END regressor__max_depth=None, regressor__min_samples_split=2, regressor__n_estimators=300;, score=-27062039530.882 total time=   5.2s
# [CV 4/5] END regressor__max_depth=None, regressor__min_samples_split=2, regressor__n_estimators=300;, score=-41932139025.340 total time=   4.0s
# [CV 5/5] END regressor__max_depth=None, regressor__min_samples_split=2, regressor__n_estimators=300;, score=-11144932543.803 total time=   4.1s
# [CV 1/5] END regressor__max_depth=None, regressor__min_samples_split=5, regressor__n_estimators=100;, score=-1071547160949.452 total time=   1.2s
# [CV 2/5] END regressor__max_depth=None, regressor__min_samples_split=5, regressor__n_estimators=100;, score=-11355740409.750 total time=   1.6s
# [CV 3/5] END regressor__max_depth=None, regressor__min_samples_split=5, regressor__n_estimators=100;, score=-82978797632.485 total time=   1.6s
# [CV 4/5] END regressor__max_depth=None, regressor__min_samples_split=5, regressor__n_estimators=100;, score=-47983417704.530 total time=   1.1s
# [CV 5/5] END regressor__max_depth=None, regressor__min_samples_split=5, regressor__n_estimators=100;, score=-10797757840.247 total time=   1.2s
# [CV 1/5] END regressor__max_depth=None, regressor__min_samples_split=5, regressor__n_estimators=175;, score=-1113157252717.343 total time=   1.9s
# [CV 2/5] END regressor__max_depth=None, regressor__min_samples_split=5, regressor__n_estimators=175;, score=-10692710672.153 total time=   2.0s
# [CV 3/5] END regressor__max_depth=None, regressor__min_samples_split=5, regressor__n_estimators=175;, score=-91766773870.126 total time=   2.0s
# [CV 4/5] END regressor__max_depth=None, regressor__min_samples_split=5, regressor__n_estimators=175;, score=-45281409629.612 total time=   2.1s
# [CV 5/5] END regressor__max_depth=None, regressor__min_samples_split=5, regressor__n_estimators=175;, score=-11044107000.165 total time=   2.9s
# [CV 2/5] END regressor__max_depth=None, regressor__min_samples_split=5, regressor__n_estimators=300;, score=-10700112638.103 total time=   3.4s
# [CV 3/5] END regressor__max_depth=None, regressor__min_samples_split=5, regressor__n_estimators=300;, score=-86153364029.415 total time=   3.4s
# [CV 4/5] END regressor__max_depth=None, regressor__min_samples_split=5, regressor__n_estimators=300;, score=-44441346831.984 total time=   4.4s
# [CV 5/5] END regressor__max_depth=None, regressor__min_samples_split=5, regressor__n_estimators=300;, score=-10688898405.727 total time=   3.4s
# [CV 1/5] END regressor__max_depth=None, regressor__min_samples_split=10, regressor__n_estimators=100;, score=-1065504605963.162 total time=   0.9s
# [CV 2/5] END regressor__max_depth=None, regressor__min_samples_split=10, regressor__n_estimators=100;, score=-10823416503.126 total time=   0.9s
# [CV 3/5] END regressor__max_depth=None, regressor__min_samples_split=10, regressor__n_estimators=100;, score=-97156143018.903 total time=   0.9s
# [CV 4/5] END regressor__max_depth=None, regressor__min_samples_split=10, regressor__n_estimators=100;, score=-42825236875.077 total time=   0.9s
# [CV 5/5] END regressor__max_depth=None, regressor__min_samples_split=10, regressor__n_estimators=100;, score=-11656657089.667 total time=   0.9s
# [CV 1/5] END regressor__max_depth=None, regressor__min_samples_split=10, regressor__n_estimators=175;, score=-1083651478201.992 total time=   1.9s
# [CV 2/5] END regressor__max_depth=None, regressor__min_samples_split=10, regressor__n_estimators=175;, score=-13005038833.861 total time=   2.3s
# [CV 3/5] END regressor__max_depth=None, regressor__min_samples_split=10, regressor__n_estimators=175;, score=-86513974999.125 total time=   1.6s
# [CV 4/5] END regressor__max_depth=None, regressor__min_samples_split=10, regressor__n_estimators=175;, score=-46564423945.787 total time=   1.6s
# [CV 5/5] END regressor__max_depth=None, regressor__min_samples_split=10, regressor__n_estimators=175;, score=-12444996797.379 total time=   1.6s
# [CV 1/5] END regressor__max_depth=None, regressor__min_samples_split=10, regressor__n_estimators=300;, score=-1115721753057.390 total time=   2.7s
# [CV 2/5] END regressor__max_depth=None, regressor__min_samples_split=10, regressor__n_estimators=300;, score=-12385945830.689 total time=   2.9s
# [CV 3/5] END regressor__max_depth=None, regressor__min_samples_split=10, regressor__n_estimators=300;, score=-83439709555.968 total time=   3.6s
# [CV 4/5] END regressor__max_depth=None, regressor__min_samples_split=10, regressor__n_estimators=300;, score=-43953525092.389 total time=   2.7s
# [CV 5/5] END regressor__max_depth=None, regressor__min_samples_split=10, regressor__n_estimators=300;, score=-12262221081.982 total time=   3.0s
# [CV 1/5] END regressor__max_depth=10, regressor__min_samples_split=2, regressor__n_estimators=100;, score=-1081427046720.423 total time=   0.7s
# [CV 2/5] END regressor__max_depth=10, regressor__min_samples_split=2, regressor__n_estimators=100;, score=-10054158676.413 total time=   0.7s
# [CV 3/5] END regressor__max_depth=10, regressor__min_samples_split=2, regressor__n_estimators=100;, score=-28089761084.991 total time=   0.7s
# [CV 4/5] END regressor__max_depth=10, regressor__min_samples_split=2, regressor__n_estimators=100;, score=-45328817842.251 total time=   0.7s
# [CV 5/5] END regressor__max_depth=10, regressor__min_samples_split=2, regressor__n_estimators=100;, score=-11896066143.525 total time=   0.7s
# [CV 1/5] END regressor__max_depth=10, regressor__min_samples_split=2, regressor__n_estimators=175;, score=-1095956253697.926 total time=   1.8s
# [CV 2/5] END regressor__max_depth=10, regressor__min_samples_split=2, regressor__n_estimators=175;, score=-12570536286.164 total time=   2.0s
# [CV 3/5] END regressor__max_depth=10, regressor__min_samples_split=2, regressor__n_estimators=175;, score=-30745720247.792 total time=   1.4s
# [CV 4/5] END regressor__max_depth=10, regressor__min_samples_split=2, regressor__n_estimators=175;, score=-42963420711.500 total time=   1.2s
# [CV 5/5] END regressor__max_depth=10, regressor__min_samples_split=2, regressor__n_estimators=175;, score=-12322510555.748 total time=   1.2s
# [CV 1/5] END regressor__max_depth=10, regressor__min_samples_split=2, regressor__n_estimators=300;, score=-1097870515014.943 total time=   2.1s
# [CV 2/5] END regressor__max_depth=10, regressor__min_samples_split=2, regressor__n_estimators=300;, score=-12208705011.511 total time=   1.9s
# [CV 3/5] END regressor__max_depth=10, regressor__min_samples_split=2, regressor__n_estimators=300;, score=-28389058284.412 total time=   2.1s
# [CV 4/5] END regressor__max_depth=10, regressor__min_samples_split=2, regressor__n_estimators=300;, score=-43656363370.917 total time=   2.9s
# [CV 5/5] END regressor__max_depth=10, regressor__min_samples_split=2, regressor__n_estimators=300;, score=-12447028855.715 total time=   2.1s
# [CV 1/5] END regressor__max_depth=10, regressor__min_samples_split=5, regressor__n_estimators=100;, score=-1118960650793.305 total time=   0.7s
# [CV 2/5] END regressor__max_depth=10, regressor__min_samples_split=5, regressor__n_estimators=100;, score=-11710716835.788 total time=   0.6s
# [CV 3/5] END regressor__max_depth=10, regressor__min_samples_split=5, regressor__n_estimators=100;, score=-91922218964.338 total time=   0.6s
# [CV 4/5] END regressor__max_depth=10, regressor__min_samples_split=5, regressor__n_estimators=100;, score=-47911003426.471 total time=   0.6s
# [CV 5/5] END regressor__max_depth=10, regressor__min_samples_split=5, regressor__n_estimators=100;, score=-12199414564.653 total time=   0.6s
# [CV 1/5] END regressor__max_depth=10, regressor__min_samples_split=5, regressor__n_estimators=175;, score=-1084450122405.318 total time=   1.1s
# [CV 2/5] END regressor__max_depth=10, regressor__min_samples_split=5, regressor__n_estimators=175;, score=-11441948023.106 total time=   1.1s
# [CV 3/5] END regressor__max_depth=10, regressor__min_samples_split=5, regressor__n_estimators=175;, score=-84663422358.267 total time=   1.1s
# [CV 4/5] END regressor__max_depth=10, regressor__min_samples_split=5, regressor__n_estimators=175;, score=-47182340779.846 total time=   1.1s
# [CV 5/5] END regressor__max_depth=10, regressor__min_samples_split=5, regressor__n_estimators=175;, score=-12127591612.084 total time=   1.4s
# [CV 1/5] END regressor__max_depth=10, regressor__min_samples_split=5, regressor__n_estimators=300;, score=-1069082200378.031 total time=   2.7s
# [CV 2/5] END regressor__max_depth=10, regressor__min_samples_split=5, regressor__n_estimators=300;, score=-11967598634.274 total time=   1.8s
# [CV 3/5] END regressor__max_depth=10, regressor__min_samples_split=5, regressor__n_estimators=300;, score=-84264631001.673 total time=   1.9s
# [CV 4/5] END regressor__max_depth=10, regressor__min_samples_split=5, regressor__n_estimators=300;, score=-47256926195.107 total time=   1.9s
# [CV 5/5] END regressor__max_depth=10, regressor__min_samples_split=5, regressor__n_estimators=300;, score=-12341720227.441 total time=   1.9s
# [CV 1/5] END regressor__max_depth=10, regressor__min_samples_split=10, regressor__n_estimators=100;, score=-1088521572008.777 total time=   0.6s
# [CV 2/5] END regressor__max_depth=10, regressor__min_samples_split=10, regressor__n_estimators=100;, score=-12695109556.019 total time=   0.6s
# [CV 3/5] END regressor__max_depth=10, regressor__min_samples_split=10, regressor__n_estimators=100;, score=-84559466886.717 total time=   0.6s
# [CV 4/5] END regressor__max_depth=10, regressor__min_samples_split=10, regressor__n_estimators=100;, score=-44212221685.968 total time=   0.7s
# [CV 5/5] END regressor__max_depth=10, regressor__min_samples_split=10, regressor__n_estimators=100;, score=-12992623283.479 total time=   0.9s
# [CV 1/5] END regressor__max_depth=10, regressor__min_samples_split=10, regressor__n_estimators=175;, score=-1089055658988.870 total time=   1.6s
# [CV 2/5] END regressor__max_depth=10, regressor__min_samples_split=10, regressor__n_estimators=175;, score=-12211890803.564 total time=   1.2s
# [CV 3/5] END regressor__max_depth=10, regressor__min_samples_split=10, regressor__n_estimators=175;, score=-86905104245.798 total time=   1.0s
# [CV 4/5] END regressor__max_depth=10, regressor__min_samples_split=10, regressor__n_estimators=175;, score=-49974848741.366 total time=   1.0s
# [CV 5/5] END regressor__max_depth=10, regressor__min_samples_split=10, regressor__n_estimators=175;, score=-13310772730.530 total time=   1.0s
# [CV 1/5] END regressor__max_depth=10, regressor__min_samples_split=10, regressor__n_estimators=300;, score=-1119895619957.652 total time=   1.8s
# [CV 2/5] END regressor__max_depth=10, regressor__min_samples_split=10, regressor__n_estimators=300;, score=-12401632656.895 total time=   1.7s
# [CV 3/5] END regressor__max_depth=10, regressor__min_samples_split=10, regressor__n_estimators=300;, score=-89763808701.809 total time=   1.8s
# [CV 4/5] END regressor__max_depth=10, regressor__min_samples_split=10, regressor__n_estimators=300;, score=-46664566665.106 total time=   2.1s
# [CV 5/5] END regressor__max_depth=10, regressor__min_samples_split=10, regressor__n_estimators=300;, score=-13156825464.061 total time=   2.4s
# [CV 1/5] END regressor__max_depth=20, regressor__min_samples_split=2, regressor__n_estimators=100;, score=-1064349731575.857 total time=   1.3s
# [CV 2/5] END regressor__max_depth=20, regressor__min_samples_split=2, regressor__n_estimators=100;, score=-10686207943.988 total time=   1.3s
# [CV 3/5] END regressor__max_depth=20, regressor__min_samples_split=2, regressor__n_estimators=100;, score=-33086668451.443 total time=   1.3s
# [CV 4/5] END regressor__max_depth=20, regressor__min_samples_split=2, regressor__n_estimators=100;, score=-43020843778.384 total time=   1.3s
# [CV 5/5] END regressor__max_depth=20, regressor__min_samples_split=2, regressor__n_estimators=100;, score=-11308137387.019 total time=   1.3s
# [CV 1/5] END regressor__max_depth=20, regressor__min_samples_split=2, regressor__n_estimators=175;, score=-1077897442020.763 total time=   2.2s
# [CV 2/5] END regressor__max_depth=20, regressor__min_samples_split=2, regressor__n_estimators=175;, score=-11708619377.562 total time=   2.7s
# [CV 3/5] END regressor__max_depth=20, regressor__min_samples_split=2, regressor__n_estimators=175;, score=-31194219441.355 total time=   2.7s
# [CV 4/5] END regressor__max_depth=20, regressor__min_samples_split=2, regressor__n_estimators=175;, score=-43103201898.835 total time=   2.2s
# [CV 5/5] END regressor__max_depth=20, regressor__min_samples_split=2, regressor__n_estimators=175;, score=-10813210048.690 total time=   2.2s
# [CV 1/5] END regressor__max_depth=20, regressor__min_samples_split=2, regressor__n_estimators=300;, score=-1070907488031.524 total time=   3.7s
# [CV 2/5] END regressor__max_depth=20, regressor__min_samples_split=2, regressor__n_estimators=300;, score=-9649740302.734 total time=   4.8s
# [CV 3/5] END regressor__max_depth=20, regressor__min_samples_split=2, regressor__n_estimators=300;, score=-30236476451.022 total time=   3.8s
# [CV 4/5] END regressor__max_depth=20, regressor__min_samples_split=2, regressor__n_estimators=300;, score=-42406221481.385 total time=   3.8s
# [CV 5/5] END regressor__max_depth=20, regressor__min_samples_split=2, regressor__n_estimators=300;, score=-10985845155.095 total time=   4.9s
# [CV 1/5] END regressor__max_depth=20, regressor__min_samples_split=5, regressor__n_estimators=100;, score=-1106712478408.974 total time=   1.1s
# [CV 2/5] END regressor__max_depth=20, regressor__min_samples_split=5, regressor__n_estimators=100;, score=-10500590486.615 total time=   1.1s
# [CV 3/5] END regressor__max_depth=20, regressor__min_samples_split=5, regressor__n_estimators=100;, score=-82877561120.080 total time=   1.1s
# [CV 4/5] END regressor__max_depth=20, regressor__min_samples_split=5, regressor__n_estimators=100;, score=-44166642872.466 total time=   1.1s
# [CV 5/5] END regressor__max_depth=20, regressor__min_samples_split=5, regressor__n_estimators=100;, score=-11245170911.718 total time=   1.1s
# [CV 1/5] END regressor__max_depth=20, regressor__min_samples_split=5, regressor__n_estimators=175;, score=-1089007548466.102 total time=   1.9s
# [CV 2/5] END regressor__max_depth=20, regressor__min_samples_split=5, regressor__n_estimators=175;, score=-10594228208.634 total time=   1.9s
# [CV 3/5] END regressor__max_depth=20, regressor__min_samples_split=5, regressor__n_estimators=175;, score=-88130922599.172 total time=   2.3s
# [CV 4/5] END regressor__max_depth=20, regressor__min_samples_split=5, regressor__n_estimators=175;, score=-45656125879.897 total time=   2.5s
# [CV 5/5] END regressor__max_depth=20, regressor__min_samples_split=5, regressor__n_estimators=175;, score=-11761329720.821 total time=   1.9s
# [CV 1/5] END regressor__max_depth=20, regressor__min_samples_split=5, regressor__n_estimators=300;, score=-1100870653975.239 total time=   3.2s
# [CV 2/5] END regressor__max_depth=20, regressor__min_samples_split=5, regressor__n_estimators=300;, score=-11522557480.195 total time=   3.2s
# [CV 3/5] END regressor__max_depth=20, regressor__min_samples_split=5, regressor__n_estimators=300;, score=-85965332893.361 total time=   4.0s
# [CV 4/5] END regressor__max_depth=20, regressor__min_samples_split=5, regressor__n_estimators=300;, score=-46480862531.724 total time=   3.3s
# [CV 5/5] END regressor__max_depth=20, regressor__min_samples_split=5, regressor__n_estimators=300;, score=-11417602378.062 total time=   3.2s
# [CV 1/5] END regressor__max_depth=20, regressor__min_samples_split=10, regressor__n_estimators=100;, score=-1060753642571.217 total time=   0.9s
# [CV 2/5] END regressor__max_depth=20, regressor__min_samples_split=10, regressor__n_estimators=100;, score=-12104813381.709 total time=   0.9s
# [CV 3/5] END regressor__max_depth=20, regressor__min_samples_split=10, regressor__n_estimators=100;, score=-93960948105.795 total time=   0.9s
# [CV 4/5] END regressor__max_depth=20, regressor__min_samples_split=10, regressor__n_estimators=100;, score=-43874029279.349 total time=   0.9s
# [CV 5/5] END regressor__max_depth=20, regressor__min_samples_split=10, regressor__n_estimators=100;, score=-12413763674.898 total time=   1.2s
# [CV 1/5] END regressor__max_depth=20, regressor__min_samples_split=10, regressor__n_estimators=175;, score=-1102059648042.958 total time=   2.2s
# [CV 2/5] END regressor__max_depth=20, regressor__min_samples_split=10, regressor__n_estimators=175;, score=-11357277185.772 total time=   1.6s
# [CV 3/5] END regressor__max_depth=20, regressor__min_samples_split=10, regressor__n_estimators=175;, score=-87753561792.245 total time=   1.6s
# [CV 4/5] END regressor__max_depth=20, regressor__min_samples_split=10, regressor__n_estimators=175;, score=-47120920082.011 total time=   1.6s
# [CV 5/5] END regressor__max_depth=20, regressor__min_samples_split=10, regressor__n_estimators=175;, score=-12191735844.435 total time=   1.6s
# [CV 1/5] END regressor__max_depth=20, regressor__min_samples_split=10, regressor__n_estimators=300;, score=-1110187995549.824 total time=   2.7s
# [CV 2/5] END regressor__max_depth=20, regressor__min_samples_split=10, regressor__n_estimators=300;, score=-11507738867.248 total time=   3.5s
# [CV 3/5] END regressor__max_depth=20, regressor__min_samples_split=10, regressor__n_estimators=300;, score=-85635088648.197 total time=   2.9s
# [CV 4/5] END regressor__max_depth=20, regressor__min_samples_split=10, regressor__n_estimators=300;, score=-46021261932.589 total time=   2.7s
# [CV 5/5] END regressor__max_depth=20, regressor__min_samples_split=10, regressor__n_estimators=300;, score=-11842735182.893 total time=   2.7s

# %%
# Assess performance
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print(f'Mean Absolute Error (MAE): {mae}')
print(f'Mean Squared Error (MSE): {mse}')
print(f'Root Mean Squared Error (RMSE): {rmse}')
print(f'R-squared (R²): {r2}')
# Out:
# Mean Absolute Error (MAE): 68996.06503939912
# Mean Squared Error (MSE): 65186591011.48753
# Root Mean Squared Error (RMSE): 255316.64852000453
# R-squared (R²): 0.7206936850635046

# %%
best_model
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   Index(['bed', 'bath', 'acre_lot', 'house_size', 'year_sold'], dtype='object')),
#                                                  ('cat',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   Index(['status', 'city', 'state', 'zip_code'], dtype='object'))])),
#                 ('regressor', RandomForestRegressor(max_depth=20))])
